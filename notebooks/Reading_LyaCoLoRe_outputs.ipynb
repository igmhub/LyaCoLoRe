# %% [markdown]
# # LyaCoLoRe outputs
#
# This notebook is to open and plot the outputfiles of LyaCoLoRe.
#
# To run LyaColore, follow steps in README file of https://github.com/igmhub/LyaCoLoRe/

# %%
# %pylab inline
import numpy as np 
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table, join
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Open output files from LyaCoLoRe

# %%
hdu=fits.open('../example_data/lya_skewers/0/0/transmission-16-0.fits')
hdu.info()
# Out:
# Filename: ../example_data/lya_skewers/0/0/transmission-16-0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  METADATA      1 BinTableHDU     23   5R x 5C   [D, D, D, D, K]
#   2  WAVELENGTH    1 ImageHDU        11   (14750,)   float64
#   3  TRANSMISSION    1 ImageHDU        12   (14750, 5)   float64
#   4  DLA           1 BinTableHDU     21   3R x 4C   [K, D, D, D]
#   5  METALS        1 ImageHDU        12   (14750, 5)   float64

# %% [markdown]
# TRANSMISSION contains Lya and Lyb, METALS contains the information of metalic lines. When running LyaCoLoRe, one can specify if Lyb and metals are wanted - see README file.
#
# Plot the transmission file

# %%
wave=hdu[2].data
plt.plot(wave,hdu['TRANSMISSION'].data[2], color= 'firebrick', label='Lya')
plt.xlabel('Wavelength [A]')
plt.ylabel('F')
plt.title('Lya+Lyb transmited flux fraction')
# Out:
# Text(0.5,1,'Lya+Lyb transmited flux fraction')

# %% [markdown]
# Metal absorption for the same spectrum

# %%
plt.plot(wave,hdu['METALS'].data[2], color= 'lightcoral', label='Metals (Si)')
plt.xlabel('Wavelength [A]')
plt.ylabel('F')
plt.title('Metal transmited flux fraction')
# Out:
# Text(0.5,1,'Metal transmited flux fraction')

# %% [markdown]
# Both!

# %%
plt.plot(wave,hdu['TRANSMISSION'].data[2], color= 'firebrick', label='Lya')
plt.plot(wave,hdu['METALS'].data[2], color= 'lightcoral', alpha=0.5, label='Metals (Si)')
plt.xlabel('Wavelength [A]')
plt.ylabel('F')
plt.title('Lya + Lyb + metals transmitted flux fraction')
plt.legend()
